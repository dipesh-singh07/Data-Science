# %% [markdown]
# <a href="https://colab.research.google.com/github/dipesh-singh07/Data-Science/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lst = [1,2,3, 'hello', 'c', [2,4]]

print(lst)

#append()
lst.append('dipesh')
print(lst)

#extend()
lst.extend([2,5,6,7])
print(lst)

#insert(index, value)
lst.insert(3,'ritesh')
print(lst)

#pop()
lst.pop()
print(lst)

#remove -> remove 1st occurance only
lst.remove(2)
print(lst)

#index()
print(lst.index(2))

#count()
print(lst.count(2))
# Out:
# [1, 2, 3, 'hello', 'c', [2, 4]]
# [1, 2, 3, 'hello', 'c', [2, 4], 'dipesh']
# [1, 2, 3, 'hello', 'c', [2, 4], 'dipesh', 2, 5, 6, 7]
# [1, 2, 3, 'ritesh', 'hello', 'c', [2, 4], 'dipesh', 2, 5, 6, 7]
# [1, 2, 3, 'ritesh', 'hello', 'c', [2, 4], 'dipesh', 2, 5, 6]
# [1, 3, 'ritesh', 'hello', 'c', [2, 4], 'dipesh', 2, 5, 6]
# 7
# 1

# %%
from re import T
lst2 = ['dipesh','singh',21,True,734007,'new jalpaiguri']
print(lst2[3])
lst2.append("ritesh singh")
lst2.insert(4,'west bengal')
print(lst2)
# Out:
# True
# ['dipesh', 'singh', 21, True, 'west bengal', 734007, 'new jalpaiguri', 'ritesh singh']

# %%
lst3 = [5,7,2,4,9]

#sort()
lst3.sort()
print(lst3)

#sum,min,max
print(min(lst3))
print(sum(lst3))
print(max(lst3))

#sorted() -> returns a new list
lst4 = [7,8,45,3,1,9]
print(sorted(lst4))
# Out:
# [2, 4, 5, 7, 9]
# 2
# 27
# 9
# [1, 3, 7, 8, 9, 45]

# %%
# touple fxn
#Catagory         Function
# count values    count()
# find            index()
# size            len()
# total           sum()
# highest/lowest  max()/min()
# sorted          sorted()(return list)

tp = (1,2,3,0)
b = tuple(sorted(tp))
print(b)
print(len(tp))
s = sum(tp)
print(s)
print(tp.index(0))
print(tp)
# Out:
# (0, 1, 2, 3)
# 4
# 6
# 3
# (1, 2, 3, 0)

# %%
a = int(input("Enter a : "))
ls1 = []
print("Enter elements in ls1 :")
for i in range(a) :
  x = int(input())
  ls1.append(x)
ls2 = []
print("Enter elements in ls2 :")
for i in range(a) :
  x = int(input())
  ls2.append(x)

ls3 = []
for i in range(a) :
  a = ls1[i] + ls2[i]
  ls3.append(a)

print(ls3)
# Out:
# Enter a : 3
# Enter elements in ls1 :
# 1
# 2
# 3
# Enter elements in ls2 :
# 3
# 2
# 1
# [4, 4, 4]
