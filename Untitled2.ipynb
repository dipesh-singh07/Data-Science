# %% [markdown]
# <a href="https://colab.research.google.com/github/dipesh-singh07/Data-Science/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add_(a, b) :
  return a + b

print(add_(1,2))
# Out:
# 3

# %%
#lambda fxn
x = lambda a : 2 * a
print(x(2))
# Out:
# 4

# %%
# st = ""
# print(len(st))

st = "   anand is a boy "
x = st.upper()
print(x) #ANAND
y = x.lower()
print(y) #anand
z = y.capitalize()
print(z)
a = z.title()
print(a)
b = a.strip(" ")
print(b)
# Out:
#    ANAND IS A BOY
#    anand is a boy
#    anand is a boy
#    Anand Is A Boy
# Anand Is A Boy

# %%
a = "  Dipesh"
b = "Singh "
print(a+b)
c = (a+b).strip(" ")
print(c)
# Out:
#   DipeshSingh
# DipeshSingh

# %%
a = " today "
b = "   weather   "
c = "is Good"
d = a.strip(" ")
e = d.capitalize()
f = b.strip(" ")
g = c.lower()
print(e + " " + f + " " + g)
x = (e + " " + f + " " + g).replace("good","bad")
print(x)
# Out:
# Today weather is good
# Today weather is bad

# %%
s = "hello world"
print(s[-3]) #calculate from last index
print(s[6 : 8])
print(s[1::])
print(s[:4])
# Out:
# r
# wo
# ello world
# hell

# %%
st = {2,2,3,56,43,9,1}
print(st)
# Out:
# {1, 2, 3, 56, 9, 43}

# %%
#dictionary
dct = {
    "fname" : "Dipesh",
    "age" : 21,
    "occupation" : "student"
}
print(dct)
print(dct["fname"])
dct["id"] = 12
print(dct)
del dct["fname"]
print(dct)
# Out:
# {'fname': 'Dipesh', 'age': 21, 'occupation': 'student'}
# Dipesh
# {'fname': 'Dipesh', 'age': 21, 'occupation': 'student', 'id': 12}
# {'age': 21, 'occupation': 'student', 'id': 12}
